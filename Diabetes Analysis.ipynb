# %%
import pandas as pd

# %%
data=pd.read_csv('diabetes.csv')

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
data['Age'].value_counts()
# Out:
# 22    72
# 21    63
# 25    48
# 24    46
# 23    38
# 28    35
# 26    33
# 27    32
# 29    29
# 31    24
# 41    22
# 30    21
# 37    19
# 42    18
# 33    17
# 38    16
# 36    16
# 32    16
# 45    15
# 34    14
# 46    13
# 43    13
# 40    13
# 39    12
# 35    10
# 50     8
# 51     8
# 52     8
# 44     8
# 58     7
# 47     6
# 54     6
# 49     5
# 48     5
# 57     5
# 53     5
# 60     5
# 66     4
# 63     4
# 62     4
# 55     4
# 67     3
# 56     3
# 59     3
# 65     3
# 69     2
# 61     2
# 72     1
# 81     1
# 64     1
# 70     1
# 68     1
# Name: Age, dtype: int64

# %%
data['SkinThickness'].value_counts()
# Out:
# 0     227
# 32     31
# 30     27
# 27     23
# 23     22
# 33     20
# 28     20
# 18     20
# 31     19
# 19     18
# 39     18
# 29     17
# 40     16
# 25     16
# 26     16
# 22     16
# 37     16
# 41     15
# 35     15
# 36     14
# 15     14
# 17     14
# 20     13
# 24     12
# 42     11
# 13     11
# 21     10
# 46      8
# 34      8
# 12      7
# 38      7
# 11      6
# 43      6
# 16      6
# 45      6
# 14      6
# 44      5
# 10      5
# 48      4
# 47      4
# 49      3
# 50      3
# 8       2
# 7       2
# 52      2
# 54      2
# 63      1
# 60      1
# 56      1
# 51      1
# 99      1
# Name: SkinThickness, dtype: int64

# %%
data['Pregnancies'].value_counts()
# Out:
# 1     135
# 0     111
# 2     103
# 3      75
# 4      68
# 5      57
# 6      50
# 7      45
# 8      38
# 9      28
# 10     24
# 11     11
# 13     10
# 12      9
# 14      2
# 15      1
# 17      1
# Name: Pregnancies, dtype: int64

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
data.shape
# Out:
# (768, 9)

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
col=['SkinThickness','Insulin','BloodPressure','Glucose','Age','DiabetesPedigreeFunction']

col_mean=data[col].mean()

data1 = data.replace(0, col_mean)

# %%
dat = pd.concat([data, data1])

# %%
import numpy as np

# %%
means = data.drop(columns=['Pregnancies', 'Outcome']).mean()

# Replace zero values with the respective mean
data = data.replace(0, np.nan)
data = data.fillna(means)
data=data.replace(np.nan , 0)
# Display the DataFrame with zero values replaced by the mean
print(data)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0            6.0    148.0           72.0      35.000000   79.799479  33.6
# 1            1.0     85.0           66.0      29.000000   79.799479  26.6
# 2            8.0    183.0           64.0      20.536458   79.799479  23.3
# 3            1.0     89.0           66.0      23.000000   94.000000  28.1
# 4            0.0    137.0           40.0      35.000000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763         10.0    101.0           76.0      48.000000  180.000000  32.9
# 764          2.0    122.0           70.0      27.000000   79.799479  36.8
# 765          5.0    121.0           72.0      23.000000  112.000000  26.2
# 766          1.0    126.0           60.0      20.536458   79.799479  30.1
# 767          1.0     93.0           70.0      31.000000   79.799479  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %% [markdown]
# DA

# %%
data1.shape
# Out:
# (768, 9)

# %%
data1.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0            6    148.0           72.0      35.000000   79.799479  33.6
# 1            1     85.0           66.0      29.000000   79.799479  26.6
# 2            8    183.0           64.0      20.536458   79.799479  23.3
# 3            1     89.0           66.0      23.000000   94.000000  28.1
# 4            0    137.0           40.0      35.000000  168.000000  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data1[data1.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
columns = list(data)[0:-1] # Excluding Outcome column which has only 
data[columns].hist(stacked=False, bins=100, figsize=(15,30), layout=(14,2));

# %%
import seaborn as sns

# %%
#coree=data.drop(columns=['Outcome']).corr()
coree=data.corr()
sns.heatmap(coree,annot=True,fmt='.1g',cmap='Greens')
# Out:
# <Axes: >

# %% [markdown]
# #### Here the features are independent to each other so we can use Naive Bayes model

# %%
#len(data.loc(data['Outcome']==1))
m=len(data.loc[data['Outcome'] == 1])
n=len(data.loc[data['Outcome']==0])
print('Percetage with diabieties',round((m/(m+n))*100,3))
print('Percetage not diabieties',round((n/(m+n))*100,3))
# Out:
# Percetage with diabieties 34.896
# Percetage not diabieties 65.104

# %%
sns.pairplot(data,diag_kind='kde')

# %%
from sklearn.model_selection import train_test_split

X = data.drop('Outcome',axis=1)     # Predictor feature columns (8 X m)

Y = data['Outcome']   # Predicted class (1=True, 0=False) (1 X m)

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=1)
# 1 is just any random seed number

x_train.head()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 88          15.0    136.0           70.0           32.0  110.000000  37.1
# 467          0.0     97.0           64.0           36.0  100.000000  36.8
# 550          1.0    116.0           70.0           28.0   79.799479  27.4
# 147          2.0    106.0           64.0           35.0  119.000000  30.5
# 481          0.0    123.0           88.0           37.0   79.799479  35.2
#
#      DiabetesPedigreeFunction  Age
# 88                      0.153   43
# 467                     0.600   25
# 550                     0.204   21
# 147                     1.400   34
# 481                     0.197   29

# %%
data[data.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
from sklearn.impute import SimpleImputer

# %%
from sklearn.naive_bayes import GaussianNB # using Gaussian algorithm from Naive Bayes

# creatw the model
diab_model = GaussianNB()

diab_model.fit(x_train, y_train.values.ravel())
# Out:
# GaussianNB()

# %%
diab_train_predict = diab_model.predict(x_train)

from sklearn import metrics

# %%
print("Model Accuracy: {0:.4f}".format(metrics.accuracy_score(y_train, diab_train_predict)))
print()
# Out:
# Model Accuracy: 0.7374

# %%
diab_test_predict = diab_model.predict(x_test)

from sklearn import metrics

print("Model Accuracy: {0:.4f}".format(metrics.accuracy_score(y_test, diab_test_predict)))
print()
# Out:
# Model Accuracy: 0.7706

# %%
import matplotlib as plt

# %%
print("Confusion Matrix")
cm=metrics.confusion_matrix(y_test, diab_test_predict, labels=[1, 0])

df_cm = pd.DataFrame(cm, index = [i for i in ["1","0"]],columns = [i for i in ["Predict 1","Predict 0"]])
#plt.figure(figsize = (7,5))
sns.heatmap(df_cm, annot=True)
# Out:
# Confusion Matrix
# <Axes: >
